# %%
import pandas as pd
import requests #to deal with links

# %%
response = requests.get("https://api.themoviedb.org/3/trending/movie/week?api_key=46680c30fecafb5fbc8dc20b666ad658")

# %% [markdown]
# import requests
#
# url = "https://api.themoviedb.org/3/account/22141754/rated/tv/episodes?language=en-US&page=1&sort_by=created_at.asc"
#
# headers = {
#     "accept": "application/json",
#     "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0NjY4MGMzMGZlY2FmYjVmYmM4ZGMyMGI2NjZhZDY1OCIsIm5iZiI6MTc1MjM0MzA0Ni42NDQsInN1YiI6IjY4NzJhMjA2ZjNmZTNjZjVjYjZlYTI1NiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.psdnvHaGFrhq1SzT79cNjdw1WUDdvhnKlQzpOq8vELs"
# }
#
# response = requests.get(url, headers=headers)
#
# print(response.text)

# %% [markdown]
# ## ?api_key=YOUR_API_KEY to insert your api key

# %% [markdown]
# ## error code 200 - fetched data successfully

# %%
pd.DataFrame(response.json()['results']).head()
# Out:
#    adult                     backdrop_path       id                   title  \
# 0  False  /g62G6aBcAcJv3ClCKmJgmHarHvq.jpg  1061474                Superman
# 1  False  /peAzdLKtT6VDWIfPQO9LJD1NCG4.jpg  1234821  Jurassic World Rebirth
# 2  False  /nKyBbFSooRPTJVqjrDteD1lF733.jpg  1011477     Karate Kid: Legends
# 3  False  /sItIskd5xpiE64bBWYwZintkGf3.jpg   541671               Ballerina
# 4  False  /rthMuZfFv4fqEU4JVbgSW9wQ8rs.jpg   986056           Thunderbolts*
#
#            original_title                                           overview  \
# 0                Superman  Superman, a journalist in Metropolis, embarks ...
# 1  Jurassic World Rebirth  Five years after the events of Jurassic World ...
# 2     Karate Kid: Legends  After a family tragedy, kung fu prodigy Li Fon...
# 3               Ballerina  Taking place during the events of John Wick: C...
# 4           Thunderbolts*  After finding themselves ensnared in a death t...
#
# ...

# %%
temp_df = pd.DataFrame(response.json()['results']).head()

# %%
temp_df
# Out:
#    adult                     backdrop_path       id                   title  \
# 0  False  /g62G6aBcAcJv3ClCKmJgmHarHvq.jpg  1061474                Superman
# 1  False  /peAzdLKtT6VDWIfPQO9LJD1NCG4.jpg  1234821  Jurassic World Rebirth
# 2  False  /nKyBbFSooRPTJVqjrDteD1lF733.jpg  1011477     Karate Kid: Legends
# 3  False  /sItIskd5xpiE64bBWYwZintkGf3.jpg   541671               Ballerina
# 4  False  /rthMuZfFv4fqEU4JVbgSW9wQ8rs.jpg   986056           Thunderbolts*
#
#            original_title                                           overview  \
# 0                Superman  Superman, a journalist in Metropolis, embarks ...
# 1  Jurassic World Rebirth  Five years after the events of Jurassic World ...
# 2     Karate Kid: Legends  After a family tragedy, kung fu prodigy Li Fon...
# 3               Ballerina  Taking place during the events of John Wick: C...
# 4           Thunderbolts*  After finding themselves ensnared in a death t...
#
# ...

# %%
df = pd.DataFrame() #making an empty dataframe to fetch all the pages in loop

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
